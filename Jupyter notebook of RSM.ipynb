# %%
from rsm import rsm

rsm('/Users/raulacevedo-esteves/rsm/tiff_files/', 'E', 'viridis', 'linear', 0, 0, 360, 75)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FBEBC8D7B80>

# %% [markdown]
# #####
